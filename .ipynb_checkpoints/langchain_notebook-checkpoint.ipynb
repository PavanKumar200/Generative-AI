# %% [markdown]
# # 🚀 LangChain Complete Notebook
# Includes API key setup inside the notebook

# %% [markdown]
# ## 🔑 Step 1: Set API Key

# %%
import os


os.environ["OPENAI_API_KEY"] = "your_new_api_key_here"

print("API Key Set:", os.getenv("OPENAI_API_KEY")[:10] + "...")
# Out:
# API Key Set: sk-proj-dt...

# %% [markdown]
# ## 🤖 Step 2: LLM Setup

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

response = llm.invoke("Explain LangChain in simple terms")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 5
#       1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI(model="gpt-4o-mini")
# ----> 5 response = llm.invoke("Explain LangChain in simple terms")
#       6 print(response.content)
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)
#     447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
# ...

# %% [markdown]
# ## 🧠 Step 3: Prompt Template

# %%
from langchain.prompts import PromptTemplate

template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

print(template.format(topic="LangChain"))

# %% [markdown]
# ## 🔗 Step 4: Chain Example

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=template)

print(chain.run("LangChain"))

# %% [markdown]
# ## 🧠 Step 5: Memory Example

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain

memory = ConversationBufferMemory()

conversation = ConversationChain(llm=llm, memory=memory)

print(conversation.predict(input="Hi, my name is Alex"))
print(conversation.predict(input="What is my name?"))

# %% [markdown]
# ## 🤖 Step 6: Agent with Tool

# %%
from langchain.agents import initialize_agent, Tool

def calculator(x):
    return eval(x)

tools = [
    Tool(name="Calculator", func=calculator, description="Performs math")
]

agent = initialize_agent(tools, llm, agent="zero-shot-react-description")

print(agent.run("What is 25 * 4?"))
